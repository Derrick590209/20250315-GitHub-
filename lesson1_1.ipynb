# %% [markdown]
# <a href="https://colab.research.google.com/github/Derrick590209/20250315-GitHub-/blob/main/lesson1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello!Python!")
# Out:
# Hello!Python!

# %% [markdown]
# python基本資料類別

# %%
15 #整數int
13.5 #浮點數float
"我是文字" #字串str
'我是Derrick'#字串str
True #布林值 bool
False #布林值 bool
# Out:
# False

# %%
5+3
7/2
7//2
7%3
3**4
3**99
# Out:
# 171792506910670443678820376588540424234035840667

# %% [markdown]
# ### 只有數值才可以數學運算

# %%
5 + 8
5.0 + 8.0
5 + 8.0
# Out:
# 13.0
